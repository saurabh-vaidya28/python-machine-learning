# %% [markdown]
# # Linear regression on company dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
advertising = pd.read_csv("company.csv")
advertising
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
print("Shape of our dataset")
print(advertising.shape)
# Out:
# Shape of our dataset
# (200, 4)

# %%
print("Info of our dataset")
print(advertising.info())
# Out:
# Info of our dataset
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.3 KB
# None

# %%
print("Describe our dataset")
print(advertising.describe())
# Out:
# Describe our dataset
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
sns.pairplot(advertising, x_vars=['TV', 'Radio', 'Newspaper'], 
            y_vars = 'Sales', height = 4, aspect = 1, kind = 'scatter')
plt.show()

# %%
X = advertising.iloc[:, :-1].values #it will give all the columns
                                    #expect the last columns
Y = advertising.iloc[:, 1].values   #it will give you the last column

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size = 0.7,
                                        test_size = 0.3, random_state = 100)
print("Training data in:")
print(X_train)
print("Training data out:")
print(Y_train)
print("Testing data in:")
print(X_test)
print("Testing data out:")
print(Y_test)
# Out:
# Training data in:
# [[213.4  24.6  13.1]
#  [151.5  41.3  58.5]
#  [205.   45.1  19.6]
#  [142.9  29.3  12.6]
#  [134.3   4.9   9.3]
#  [ 80.2   0.    9.2]
#  [239.8   4.1  36.9]
#  [ 88.3  25.5  73.4]
#  [ 19.4  16.   22.3]
#  [225.8   8.2  56.5]
#  [136.2  19.2  16.6]
#  [ 25.1  25.7  43.3]
#  [ 38.   40.3  11.9]
#  [172.5  18.1  30.7]
#  [109.8  47.8  51.4]
#  [240.1   7.3   8.7]
#  [232.1   8.6   8.7]
#  [ 66.1   5.8  24.2]
#  [218.4  27.7  53.4]
#  [234.5   3.4  84.8]
#  [ 23.8  35.1  65.9]
#  [ 67.8  36.6 114. ]
#  [296.4  36.3 100.9]
#  [141.3  26.8  46.2]
#  [175.1  22.5  31.5]
#  [220.5  33.2  37.9]
#  [ 76.4   0.8  14.8]
#  [253.8  21.3  30. ]
#  [191.1  28.7  18.2]
#  [287.6  43.   71.8]
#  [100.4   9.6   3.6]
#  [228.   37.7  32. ]
#  [125.7  36.9  79.2]
#  [ 74.7  49.4  45.7]
#  [ 57.5  32.8  23.5]
#  [262.7  28.8  15.9]
#  [262.9   3.5  19.5]
#  [237.4   5.1  23.5]
#  [227.2  15.8  49.9]
#  [199.8   2.6  21.2]
#  [228.3  16.9  26.2]
#  [290.7   4.1   8.5]
# ...

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, Y_train)
Y_pred = regressor.predict(X_test)
df = pd.DataFrame({'Actual': Y_test, 'Predicted': Y_pred})
print(df)
# Out:
#     Actual  Predicted
# 0     38.9       38.9
# 1     34.3       34.3
# 2     41.7       41.7
# 3     33.5       33.5
# 4     38.0       38.0
# 5      5.2        5.2
# 6     14.3       14.3
# 7      3.5        3.5
# 8     41.7       41.7
# 9     43.9       43.9
# 10    14.7       14.7
# 11    32.3       32.3
# 12     5.7        5.7
# 13    21.1       21.1
# 14    11.8       11.8
# 15     4.9        4.9
# 16    35.6       35.6
# 17     7.8        7.8
# 18    36.8       36.8
# 19    17.4       17.4
# 20    24.0       24.0
# 21     5.7        5.7
# 22    47.7       47.7
# 23    33.4       33.4
# 24    21.0       21.0
# 25    49.0       49.0
# 26    33.5       33.5
# 27    20.3       20.3
# 28    43.9       43.9
# 29    34.6       34.6
# 30    44.5       44.5
# 31     9.3        9.3
# 32     8.4        8.4
# 33    18.1       18.1
# 34    11.6       11.6
# 35    28.5       28.5
# 36     1.5        1.5
# 37     7.1        7.1
# 38     3.4        3.4
# 39    18.4       18.4
# ...

# %%
print("\nRegressor Intercept")
print(regressor.intercept_)
print("\nRegressor Coefficient")
print(regressor.coef_)
print("\nRegressor Score")
print(regressor.score(X, Y))
# Out:
# Regressor Intercept
# 1.4210854715202004e-14
#
# Regressor Coefficient
# [ 8.11213577e-18  1.00000000e+00 -5.55111512e-16]
#
# Regressor Score
# 1.0
